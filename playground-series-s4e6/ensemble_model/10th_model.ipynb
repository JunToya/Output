# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.manifold import MDS, TSNE

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score

import seaborn as sns
import lightgbm as lgb
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
train_df = pd.read_csv("../train.csv")
test_df = pd.read_csv("../test.csv")

sub_df = pd.read_csv("../sample_submission.csv")

# %%
train_df.describe(include='all').T
# Out:
#                                                   count unique       top  \
# id                                              76518.0    NaN       NaN
# Marital status                                  76518.0    NaN       NaN
# Application mode                                76518.0    NaN       NaN
# Application order                               76518.0    NaN       NaN
# Course                                          76518.0    NaN       NaN
# Daytime/evening attendance                      76518.0    NaN       NaN
# Previous qualification                          76518.0    NaN       NaN
# Previous qualification (grade)                  76518.0    NaN       NaN
# Nacionality                                     76518.0    NaN       NaN
# Mother's qualification                          76518.0    NaN       NaN
# Father's qualification                          76518.0    NaN       NaN
# Mother's occupation                             76518.0    NaN       NaN
# Father's occupation                             76518.0    NaN       NaN
# Admission grade                                 76518.0    NaN       NaN
# Displaced                                       76518.0    NaN       NaN
# Educational special needs                       76518.0    NaN       NaN
# Debtor                                          76518.0    NaN       NaN
# Tuition fees up to date                         76518.0    NaN       NaN
# Gender                                          76518.0    NaN       NaN
# Scholarship holder                              76518.0    NaN       NaN
# Age at enrollment                               76518.0    NaN       NaN
# International                                   76518.0    NaN       NaN
# Curricular units 1st sem (credited)             76518.0    NaN       NaN
# Curricular units 1st sem (enrolled)             76518.0    NaN       NaN
# Curricular units 1st sem (evaluations)          76518.0    NaN       NaN
# Curricular units 1st sem (approved)             76518.0    NaN       NaN
# Curricular units 1st sem (grade)                76518.0    NaN       NaN
# Curricular units 1st sem (without evaluations)  76518.0    NaN       NaN
# Curricular units 2nd sem (credited)             76518.0    NaN       NaN
# Curricular units 2nd sem (enrolled)             76518.0    NaN       NaN
# Curricular units 2nd sem (evaluations)          76518.0    NaN       NaN
# Curricular units 2nd sem (approved)             76518.0    NaN       NaN
# Curricular units 2nd sem (grade)                76518.0    NaN       NaN
# Curricular units 2nd sem (without evaluations)  76518.0    NaN       NaN
# Unemployment rate                               76518.0    NaN       NaN
# Inflation rate                                  76518.0    NaN       NaN
# GDP                                             76518.0    NaN       NaN
# Target                                            76518      3  Graduate
#
#                                                  freq         mean  \
# id                                                NaN      38258.5
# Marital status                                    NaN     1.111934
# Application mode                                  NaN    16.054419
# Application order                                 NaN      1.64441
# Course                                            NaN  9001.286377
# Daytime/evening attendance                        NaN     0.915314
# Previous qualification                            NaN      3.65876
# Previous qualification (grade)                    NaN   132.378766
# Nacionality                                       NaN       1.2266
# Mother's qualification                            NaN    19.837633
# Father's qualification                            NaN    23.425076
# Mother's occupation                               NaN     8.583196
# Father's occupation                               NaN     8.882172
# Admission grade                                   NaN   125.363971
# Displaced                                         NaN     0.569265
# Educational special needs                         NaN     0.003738
# Debtor                                            NaN     0.071382
# Tuition fees up to date                           NaN     0.893646
# Gender                                            NaN     0.315821
# Scholarship holder                                NaN     0.247393
# Age at enrollment                                 NaN    22.278653
# International                                     NaN     0.006626
# Curricular units 1st sem (credited)               NaN     0.188871
# Curricular units 1st sem (enrolled)               NaN     5.891516
# Curricular units 1st sem (evaluations)            NaN     7.352362
# Curricular units 1st sem (approved)               NaN      4.17852
# Curricular units 1st sem (grade)                  NaN     9.995862
# Curricular units 1st sem (without evaluations)    NaN      0.05796
# Curricular units 2nd sem (credited)               NaN     0.137053
# Curricular units 2nd sem (enrolled)               NaN     5.933414
# Curricular units 2nd sem (evaluations)            NaN     7.234468
# Curricular units 2nd sem (approved)               NaN     4.007201
# Curricular units 2nd sem (grade)                  NaN     9.626085
# Curricular units 2nd sem (without evaluations)    NaN     0.062443
# Unemployment rate                                 NaN     11.52034
# Inflation rate                                    NaN     1.228218
# GDP                                               NaN    -0.080921
# Target                                          36282          NaN
#
#                                                          std   min        25%  \
# id                                              22088.988286   0.0   19129.25
# Marital status                                      0.441669   1.0        1.0
# Application mode                                   16.682337   1.0        1.0
# Application order                                   1.229645   0.0        1.0
# Course                                           1803.438531  33.0     9119.0
# Daytime/evening attendance                          0.278416   0.0        1.0
# Previous qualification                              8.623774   1.0        1.0
# Previous qualification (grade)                     10.995328  95.0      125.0
# Nacionality                                         3.392183   1.0        1.0
# Mother's qualification                             15.399456   1.0        1.0
# Father's qualification                             14.921164   1.0        4.0
# Mother's occupation                                17.471591   0.0        4.0
# Father's occupation                                 16.80394   0.0        5.0
# Admission grade                                    12.562328  95.0      118.0
# Displaced                                           0.495182   0.0        0.0
# Educational special needs                           0.061023   0.0        0.0
# Debtor                                              0.257463   0.0        0.0
# Tuition fees up to date                             0.308292   0.0        1.0
# Gender                                              0.464845   0.0        0.0
# Scholarship holder                                    0.4315   0.0        0.0
# Age at enrollment                                   6.889241  17.0       18.0
# International                                        0.08113   0.0        0.0
# Curricular units 1st sem (credited)                 1.175296   0.0        0.0
# Curricular units 1st sem (enrolled)                 1.671776   0.0        5.0
# Curricular units 1st sem (evaluations)              3.508292   0.0        6.0
# Curricular units 1st sem (approved)                 2.687995   0.0        2.0
# Curricular units 1st sem (grade)                    5.264224   0.0  10.666667
# Curricular units 1st sem (without evaluations)       0.40849   0.0        0.0
# Curricular units 2nd sem (credited)                  0.93383   0.0        0.0
# Curricular units 2nd sem (enrolled)                 1.627182   0.0        5.0
# Curricular units 2nd sem (evaluations)               3.50304   0.0        6.0
# Curricular units 2nd sem (approved)                 2.772956   0.0        1.0
# Curricular units 2nd sem (grade)                    5.546035   0.0       10.0
# Curricular units 2nd sem (without evaluations)      0.462107   0.0        0.0
# Unemployment rate                                   2.653375   7.6        9.4
# Inflation rate                                      1.398816  -0.8        0.3
# GDP                                                 2.251382 -4.06       -1.7
# Target                                                   NaN   NaN        NaN
#
#                                                       50%        75%      max
# id                                                38258.5   57387.75  76517.0
# Marital status                                        1.0        1.0      6.0
# Application mode                                     17.0       39.0     53.0
# Application order                                     1.0        2.0      9.0
# Course                                             9254.0     9670.0   9991.0
# Daytime/evening attendance                            1.0        1.0      1.0
# Previous qualification                                1.0        1.0     43.0
# Previous qualification (grade)                      133.1      140.0    190.0
# Nacionality                                           1.0        1.0    109.0
# Mother's qualification                               19.0       37.0     44.0
# Father's qualification                               19.0       37.0     44.0
# Mother's occupation                                   7.0        9.0    194.0
# Father's occupation                                   7.0        9.0    195.0
# Admission grade                                     124.6      132.0    190.0
# Displaced                                             1.0        1.0      1.0
# Educational special needs                             0.0        0.0      1.0
# Debtor                                                0.0        0.0      1.0
# Tuition fees up to date                               1.0        1.0      1.0
# Gender                                                0.0        1.0      1.0
# Scholarship holder                                    0.0        0.0      1.0
# Age at enrollment                                    19.0       23.0     70.0
# International                                         0.0        0.0      1.0
# Curricular units 1st sem (credited)                   0.0        0.0     20.0
# Curricular units 1st sem (enrolled)                   6.0        6.0     26.0
# Curricular units 1st sem (evaluations)                7.0        9.0     45.0
# Curricular units 1st sem (approved)                   5.0        6.0     26.0
# Curricular units 1st sem (grade)                12.166667  13.314286   18.875
# Curricular units 1st sem (without evaluations)        0.0        0.0     12.0
# Curricular units 2nd sem (credited)                   0.0        0.0     19.0
# Curricular units 2nd sem (enrolled)                   6.0        6.0     23.0
# Curricular units 2nd sem (evaluations)                7.0        9.0     33.0
# Curricular units 2nd sem (approved)                   5.0        6.0     20.0
# Curricular units 2nd sem (grade)                12.142857  13.244048     18.0
# Curricular units 2nd sem (without evaluations)        0.0        0.0     12.0
# Unemployment rate                                    11.1       12.7     16.2
# Inflation rate                                        1.4        2.6      3.7
# GDP                                                  0.32       1.79     3.51
# Target                                                NaN        NaN      NaN

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              76518 non-null  int64
#  1   Marital status                                  76518 non-null  int64
#  2   Application mode                                76518 non-null  int64
#  3   Application order                               76518 non-null  int64
#  4   Course                                          76518 non-null  int64
#  5   Daytime/evening attendance                      76518 non-null  int64
#  6   Previous qualification                          76518 non-null  int64
#  7   Previous qualification (grade)                  76518 non-null  float64
#  8   Nacionality                                     76518 non-null  int64
#  9   Mother's qualification                          76518 non-null  int64
#  10  Father's qualification                          76518 non-null  int64
#  11  Mother's occupation                             76518 non-null  int64
#  12  Father's occupation                             76518 non-null  int64
#  13  Admission grade                                 76518 non-null  float64
#  14  Displaced                                       76518 non-null  int64
#  15  Educational special needs                       76518 non-null  int64
#  16  Debtor                                          76518 non-null  int64
#  17  Tuition fees up to date                         76518 non-null  int64
#  18  Gender                                          76518 non-null  int64
#  19  Scholarship holder                              76518 non-null  int64
#  20  Age at enrollment                               76518 non-null  int64
#  21  International                                   76518 non-null  int64
#  22  Curricular units 1st sem (credited)             76518 non-null  int64
#  23  Curricular units 1st sem (enrolled)             76518 non-null  int64
#  24  Curricular units 1st sem (evaluations)          76518 non-null  int64
#  25  Curricular units 1st sem (approved)             76518 non-null  int64
#  26  Curricular units 1st sem (grade)                76518 non-null  float64
#  27  Curricular units 1st sem (without evaluations)  76518 non-null  int64
#  28  Curricular units 2nd sem (credited)             76518 non-null  int64
#  29  Curricular units 2nd sem (enrolled)             76518 non-null  int64
#  30  Curricular units 2nd sem (evaluations)          76518 non-null  int64
#  31  Curricular units 2nd sem (approved)             76518 non-null  int64
#  32  Curricular units 2nd sem (grade)                76518 non-null  float64
#  33  Curricular units 2nd sem (without evaluations)  76518 non-null  int64
#  34  Unemployment rate                               76518 non-null  float64
#  35  Inflation rate                                  76518 non-null  float64
#  36  GDP                                             76518 non-null  float64
#  37  Target                                          76518 non-null  object
# dtypes: float64(7), int64(30), object(1)
# memory usage: 22.2+ MB

# %%
train_df.nunique().sort_values()
# Out:
# Gender                                                2
# International                                         2
# Scholarship holder                                    2
# Tuition fees up to date                               2
# Debtor                                                2
# Daytime/evening attendance                            2
# Educational special needs                             2
# Displaced                                             2
# Target                                                3
# Marital status                                        6
# Application order                                     8
# Unemployment rate                                    11
# Curricular units 2nd sem (without evaluations)       11
# GDP                                                  11
# Curricular units 1st sem (without evaluations)       12
# Inflation rate                                       13
# Nacionality                                          18
# Course                                               19
# Curricular units 2nd sem (credited)                  20
# Previous qualification                               21
# Curricular units 2nd sem (approved)                  21
# Curricular units 1st sem (credited)                  21
# Application mode                                     22
# Curricular units 2nd sem (enrolled)                  22
# Curricular units 1st sem (approved)                  23
# Curricular units 1st sem (enrolled)                  24
# Curricular units 2nd sem (evaluations)               31
# Mother's qualification                               35
# Curricular units 1st sem (evaluations)               36
# Father's qualification                               39
# Mother's occupation                                  40
# Age at enrollment                                    46
# Father's occupation                                  56
# Previous qualification (grade)                      110
# Admission grade                                     668
# Curricular units 1st sem (grade)                   1206
# Curricular units 2nd sem (grade)                   1234
# id                                                76518
# dtype: int64

# %%
feature_list = [feature for feature in train_df.columns if  feature  != "Target"]

target = "Target"

binary_features = ['Scholarship holder','International','Gender','Tuition fees up to date',
                   'Daytime/evening attendance','Debtor','Educational special needs','Displaced']

#from data set description
categorical_features = ['Marital status', 'Unemployment rate', 'Curricular units 2nd sem (without evaluations)', 'GDP', 
                        'Curricular units 1st sem (without evaluations)', 'Inflation rate', 'Nacionality', 'Course',
                        'Curricular units 2nd sem (credited)', 'Previous qualification', 'Curricular units 2nd sem (approved)',
                        'Curricular units 1st sem (credited)', 'Application mode', 'Curricular units 2nd sem (enrolled)', 
                        'Curricular units 1st sem (approved)', 'Curricular units 1st sem (enrolled)', 'Curricular units 2nd sem (evaluations)',
                        "Mother's qualification", 'Curricular units 1st sem (evaluations)', "Father's qualification", "Mother's occupation",
                        'Age at enrollment', "Father's occupation"]

train_df[categorical_features] = train_df[categorical_features].astype('category')
test_df[categorical_features] = test_df[categorical_features].astype('category')


numeric_features = list(set(feature_list) - set(binary_features)- set(categorical_features))

assert sorted(feature_list) == sorted(numeric_features + binary_features + categorical_features)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

sc = StandardScaler()
oe = OneHotEncoder(drop='first', handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', sc, numeric_features),
        ('cat', oe, categorical_features),
        ('bin', 'passthrough', binary_features)
    ])

# %%
# 前処理の実行
data_preprocessed = preprocessor.fit_transform(train_df)
test_preprocessed = preprocessor.transform(test_df)

# 疎行列を密行列に変換し、書き込み可能なコピーを作成
if hasattr(data_preprocessed, 'toarray'):
    data_preprocessed = data_preprocessed.toarray()
else:
    data_preprocessed = np.array(data_preprocessed, copy=True)

if hasattr(test_preprocessed, 'toarray'):
    test_preprocessed = test_preprocessed.toarray()
else:
    test_preprocessed = np.array(test_preprocessed, copy=True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [1, 5, 6, 7, 9, 12, 13, 14, 15, 16, 17, 18, 19, 20, 22] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# OneHotEncoderによって生成された特徴量名を取得
encoded_features = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_features)

# 全ての特徴量名を結合
all_features = numeric_features + list(encoded_features) + binary_features

# 前処理されたデータをDataFrameに変換
df_preprocessed = pd.DataFrame(data_preprocessed, columns=all_features)
test_preprocessed = pd.DataFrame(test_preprocessed, columns=all_features)

# %%
X = df_preprocessed.drop('id', axis=1)
y = train_df.loc[:, 'Target']

label_mapping = {'Dropout': 0, 'Enrolled': 1, 'Graduate': 2}
encoded_y = y.map(label_mapping)

# %%
import lightgbm as lgb
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, LambdaCallback
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import VotingClassifier
from sklearn.base import BaseEstimator, ClassifierMixin
from lightgbm import LGBMClassifier
import numpy as np

# データの準備（例）
# data_preprocessed, encoded_y, test_preprocessed, test_df などを事前に用意する

# データの分割
X_train, X_val, y_train, y_val = train_test_split(X, encoded_y, test_size=0.2, random_state=42)

# SMOTEによるオーバーサンプリング
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# LightGBMのモデル定義
lgb_params = {
    'objective': 'multiclass',
    'num_class': 3,
    'metric': 'multi_logloss',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

lgb_model = LGBMClassifier(**lgb_params)
lgb_model.fit(X_train_smote, y_train_smote)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.048857 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 44281
# [LightGBM] [Info] Number of data points in the train set: 87069, number of used features: 350
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# LGBMClassifier(feature_fraction=0.9, learning_rate=0.05, metric='multi_logloss',
#                num_class=3, objective='multiclass')

# %%
# Kerasのニューラルネットワークモデル定義
def create_nn_model(input_dim):
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

nn_model = create_nn_model(X_train_smote.shape[1])

# アーリーストッピングのコールバック
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

nn_model.fit(X_train_smote, y_train_smote, epochs=20, batch_size=32, validation_data=(X_val, y_val), verbose=1, callbacks=[early_stopping])
# Out:
# 2024-06-27 10:56:53.662974: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-06-27 10:56:53.663002: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-06-27 10:56:53.663016: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-06-27 10:56:53.663040: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-27 10:56:53.663063: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/20
# 2024-06-27 10:56:54.551897: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - accuracy: 0.7389 - loss: 0.6419 - val_accuracy: 0.8181 - val_loss: 0.4766
# Epoch 2/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8013 - loss: 0.5241 - val_accuracy: 0.8172 - val_loss: 0.4740
# Epoch 3/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8052 - loss: 0.5078 - val_accuracy: 0.8157 - val_loss: 0.4839
# Epoch 4/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 315s 116ms/step - accuracy: 0.8115 - loss: 0.4920 - val_accuracy: 0.8177 - val_loss: 0.4756
# Epoch 5/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8158 - loss: 0.4809 - val_accuracy: 0.8225 - val_loss: 0.4700
# Epoch 6/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8208 - loss: 0.4724 - val_accuracy: 0.8248 - val_loss: 0.4653
# Epoch 7/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8237 - loss: 0.4627 - val_accuracy: 0.8249 - val_loss: 0.4683
# Epoch 8/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8268 - loss: 0.4600 - val_accuracy: 0.8221 - val_loss: 0.4724
# Epoch 9/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - accuracy: 0.8306 - loss: 0.4532 - val_accuracy: 0.8229 - val_loss: 0.4709
# Epoch 10/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8337 - loss: 0.4439 - val_accuracy: 0.8227 - val_loss: 0.4727
# Epoch 11/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - accuracy: 0.8357 - loss: 0.4366 - val_accuracy: 0.8228 - val_loss: 0.4713
# Epoch 12/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - accuracy: 0.8380 - loss: 0.4346 - val_accuracy: 0.8251 - val_loss: 0.4703
# Epoch 13/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8396 - loss: 0.4300 - val_accuracy: 0.8246 - val_loss: 0.4814
# Epoch 14/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.8419 - loss: 0.4258 - val_accuracy: 0.8245 - val_loss: 0.4807
# Epoch 15/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - accuracy: 0.8407 - loss: 0.4251 - val_accuracy: 0.8236 - val_loss: 0.4837
# Epoch 16/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 42s 15ms/step - accuracy: 0.8417 - loss: 0.4243 - val_accuracy: 0.8200 - val_loss: 0.4938

# %%
from tensorflow.keras.callbacks import LambdaCallback

# カスタムクラスを定義してKerasモデルをscikit-learnと統合
class KerasClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, model):
        self.model = model

    def fit(self, X, y):
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        log_callback = LambdaCallback(on_epoch_end=lambda epoch, logs: print(f"Epoch {epoch+1}: loss = {logs['loss']}, val_loss = {logs['val_loss']}"))
        self.model.fit(X, y, epochs=20, batch_size=32, verbose=1, validation_data=(X_val, y_val), callbacks=[early_stopping, log_callback])
        return self

    def predict(self, X):
        y_pred = self.model.predict(X)
        return np.argmax(y_pred, axis=1)

    def predict_proba(self, X):
        return self.model.predict(X)

keras_clf = KerasClassifier(model=create_nn_model(X_train_smote.shape[1]))
keras_clf.fit(X_train_smote, y_train_smote)
# Out:
# Epoch 1/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7704 - loss: 0.5804Epoch 1: loss = 0.5197274088859558, val_loss = 1.0454291105270386
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.7704 - loss: 0.5804 - val_accuracy: 0.5764 - val_loss: 1.0454
# Epoch 2/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8235 - loss: 0.4663Epoch 2: loss = 0.4715453088283539, val_loss = 1.0312035083770752
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.8235 - loss: 0.4663 - val_accuracy: 0.5460 - val_loss: 1.0312
# Epoch 3/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8229 - loss: 0.4640Epoch 3: loss = 0.46162864565849304, val_loss = 0.9958347678184509
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 15ms/step - accuracy: 0.8229 - loss: 0.4640 - val_accuracy: 0.5458 - val_loss: 0.9958
# Epoch 4/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8285 - loss: 0.4505Epoch 4: loss = 0.45329806208610535, val_loss = 0.9107313752174377
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 17ms/step - accuracy: 0.8285 - loss: 0.4505 - val_accuracy: 0.6293 - val_loss: 0.9107
# Epoch 5/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8280 - loss: 0.4486Epoch 5: loss = 0.4483640789985657, val_loss = 0.8987284898757935
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 17ms/step - accuracy: 0.8280 - loss: 0.4486 - val_accuracy: 0.6107 - val_loss: 0.8987
# Epoch 6/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8322 - loss: 0.4402Epoch 6: loss = 0.4428817629814148, val_loss = 0.8629418015480042
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 37s 17ms/step - accuracy: 0.8322 - loss: 0.4402 - val_accuracy: 0.6456 - val_loss: 0.8629
# Epoch 7/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8324 - loss: 0.4391Epoch 7: loss = 0.43975841999053955, val_loss = 0.9190866351127625
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 16ms/step - accuracy: 0.8324 - loss: 0.4391 - val_accuracy: 0.6051 - val_loss: 0.9191
# Epoch 8/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8358 - loss: 0.4269Epoch 8: loss = 0.4328504204750061, val_loss = 0.9352477192878723
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.8358 - loss: 0.4269 - val_accuracy: 0.6154 - val_loss: 0.9352
# Epoch 9/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8335 - loss: 0.4318Epoch 9: loss = 0.42862388491630554, val_loss = 0.8163439035415649
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 17ms/step - accuracy: 0.8335 - loss: 0.4318 - val_accuracy: 0.6545 - val_loss: 0.8163
# Epoch 10/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8392 - loss: 0.4190Epoch 10: loss = 0.4242764413356781, val_loss = 0.9234658479690552
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 17ms/step - accuracy: 0.8392 - loss: 0.4190 - val_accuracy: 0.6039 - val_loss: 0.9235
# Epoch 11/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8408 - loss: 0.4206Epoch 11: loss = 0.4227466583251953, val_loss = 0.8371196389198303
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 84s 39ms/step - accuracy: 0.8408 - loss: 0.4206 - val_accuracy: 0.6541 - val_loss: 0.8371
# Epoch 12/20
# 2174/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8414 - loss: 0.4195Epoch 12: loss = 0.4197489023208618, val_loss = 0.8731216192245483
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 16ms/step - accuracy: 0.8413 - loss: 0.4195 - val_accuracy: 0.6341 - val_loss: 0.8731
# Epoch 13/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8437 - loss: 0.4140Epoch 13: loss = 0.4162660837173462, val_loss = 0.8969321250915527
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.8437 - loss: 0.4140 - val_accuracy: 0.6272 - val_loss: 0.8969
# Epoch 14/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8401 - loss: 0.4115Epoch 14: loss = 0.4118278920650482, val_loss = 0.9240204691886902
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 17ms/step - accuracy: 0.8401 - loss: 0.4115 - val_accuracy: 0.6257 - val_loss: 0.9240
# Epoch 15/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8456 - loss: 0.4076Epoch 15: loss = 0.41125425696372986, val_loss = 0.8944993019104004
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 17ms/step - accuracy: 0.8456 - loss: 0.4077 - val_accuracy: 0.6238 - val_loss: 0.8945
# Epoch 16/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8446 - loss: 0.4037Epoch 16: loss = 0.40698695182800293, val_loss = 0.9141185879707336
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.8446 - loss: 0.4037 - val_accuracy: 0.6197 - val_loss: 0.9141
# Epoch 17/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8475 - loss: 0.4019Epoch 17: loss = 0.4055975377559662, val_loss = 0.8776434063911438
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 17ms/step - accuracy: 0.8475 - loss: 0.4019 - val_accuracy: 0.6283 - val_loss: 0.8776
# Epoch 18/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8500 - loss: 0.3947Epoch 18: loss = 0.4010978043079376, val_loss = 0.7232918739318848
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.8500 - loss: 0.3947 - val_accuracy: 0.7014 - val_loss: 0.7233
# Epoch 19/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8474 - loss: 0.4017Epoch 19: loss = 0.40128350257873535, val_loss = 0.8618804216384888
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8474 - loss: 0.4017 - val_accuracy: 0.6484 - val_loss: 0.8619
# Epoch 20/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8482 - loss: 0.3989Epoch 20: loss = 0.399357408285141, val_loss = 0.8119753003120422
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8482 - loss: 0.3989 - val_accuracy: 0.6567 - val_loss: 0.8120
# KerasClassifier(model=<Sequential name=sequential_4, built=True>)

# %%
# アンサンブルモデルの定義
ensemble_model = VotingClassifier(estimators=[
    ('lgb', lgb_model),
    ('nn', keras_clf)
], voting='soft')

# 検証データでの予測
ensemble_model.fit(X_train_smote, y_train_smote)
y_pred_ensemble = ensemble_model.predict(X_val)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.050891 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 44281
# [LightGBM] [Info] Number of data points in the train set: 87069, number of used features: 350
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# Epoch 1/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8501 - loss: 0.3969Epoch 1: loss = 0.4001912474632263, val_loss = 0.8521767854690552
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 36s 16ms/step - accuracy: 0.8501 - loss: 0.3969 - val_accuracy: 0.6357 - val_loss: 0.8522
# Epoch 2/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8498 - loss: 0.3945Epoch 2: loss = 0.39894500374794006, val_loss = 0.8797147274017334
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8498 - loss: 0.3945 - val_accuracy: 0.6147 - val_loss: 0.8797
# Epoch 3/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8523 - loss: 0.3868Epoch 3: loss = 0.3954756557941437, val_loss = 0.8241281509399414
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8523 - loss: 0.3868 - val_accuracy: 0.6478 - val_loss: 0.8241
# Epoch 4/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8492 - loss: 0.3968Epoch 4: loss = 0.39492687582969666, val_loss = 0.8380782604217529
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8492 - loss: 0.3968 - val_accuracy: 0.6224 - val_loss: 0.8381
# Epoch 5/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8523 - loss: 0.3887Epoch 5: loss = 0.39485999941825867, val_loss = 0.8591353893280029
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8523 - loss: 0.3887 - val_accuracy: 0.6207 - val_loss: 0.8591
# Epoch 6/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8523 - loss: 0.3885Epoch 6: loss = 0.39161932468414307, val_loss = 0.7495519518852234
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8523 - loss: 0.3885 - val_accuracy: 0.6762 - val_loss: 0.7496
# Epoch 7/20
# 2174/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8533 - loss: 0.3861Epoch 7: loss = 0.3895079791545868, val_loss = 0.8596180081367493
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8533 - loss: 0.3861 - val_accuracy: 0.6229 - val_loss: 0.8596
# Epoch 8/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8546 - loss: 0.3770Epoch 8: loss = 0.38731372356414795, val_loss = 0.8435177206993103
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8546 - loss: 0.3770 - val_accuracy: 0.6404 - val_loss: 0.8435
# Epoch 9/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8528 - loss: 0.3865Epoch 9: loss = 0.38853344321250916, val_loss = 0.794608473777771
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8528 - loss: 0.3865 - val_accuracy: 0.6733 - val_loss: 0.7946
# Epoch 10/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8541 - loss: 0.3842Epoch 10: loss = 0.38696885108947754, val_loss = 0.837949275970459
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8541 - loss: 0.3842 - val_accuracy: 0.6336 - val_loss: 0.8379
# Epoch 11/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8566 - loss: 0.3777Epoch 11: loss = 0.3836783170700073, val_loss = 0.831670880317688
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 15ms/step - accuracy: 0.8566 - loss: 0.3777 - val_accuracy: 0.6507 - val_loss: 0.8317
# Epoch 12/20
# 2175/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8553 - loss: 0.3778Epoch 12: loss = 0.3835544288158417, val_loss = 0.8313271999359131
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 35s 16ms/step - accuracy: 0.8553 - loss: 0.3778 - val_accuracy: 0.6585 - val_loss: 0.8313
# Epoch 13/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8547 - loss: 0.3791Epoch 13: loss = 0.3827461004257202, val_loss = 0.7938059568405151
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8547 - loss: 0.3791 - val_accuracy: 0.6532 - val_loss: 0.7938
# Epoch 14/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8576 - loss: 0.3783Epoch 14: loss = 0.3811524212360382, val_loss = 0.7661436796188354
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8576 - loss: 0.3783 - val_accuracy: 0.6760 - val_loss: 0.7661
# Epoch 15/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8597 - loss: 0.3747Epoch 15: loss = 0.3797902464866638, val_loss = 0.8093476891517639
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8597 - loss: 0.3747 - val_accuracy: 0.6567 - val_loss: 0.8093
# Epoch 16/20
# 2176/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8579 - loss: 0.3748Epoch 16: loss = 0.37739840149879456, val_loss = 0.838818371295929
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 34s 16ms/step - accuracy: 0.8579 - loss: 0.3748 - val_accuracy: 0.6300 - val_loss: 0.8388
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# 479/479 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
# 評価
accuracy_ensemble = accuracy_score(y_val, y_pred_ensemble)
print(f'Ensemble Validation Accuracy: {accuracy_ensemble}')
print(classification_report(y_val, y_pred_ensemble))
# Out:
# Ensemble Validation Accuracy: 0.8312859383167799
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87      5028
#            1       0.65      0.60      0.62      3017
#            2       0.86      0.92      0.89      7259
#
#     accuracy                           0.83     15304
#    macro avg       0.80      0.79      0.79     15304
# weighted avg       0.83      0.83      0.83     15304

# %%
# テストデータに対する予測
test_preprocessed = test_preprocessed.drop('id', axis=1)
test_pred_ensemble = ensemble_model.predict(test_preprocessed)

# ターゲット値に変換
target_mapping = {0: 'Dropout', 1: 'Enrolled', 2: 'Graduate'}
final_predictions = [target_mapping[pred] for pred in test_pred_ensemble]

# 結果をデータフレームに格納
results_df = pd.DataFrame(data={"id": test_df['id'], "Target": final_predictions})

# 結果を保存
results_df.to_csv('submission_ensemble.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# Your submission was successfully saved!
