# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.manifold import MDS, TSNE

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score

import seaborn as sns
import lightgbm as lgb
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
train_df = pd.read_csv("../train.csv")
test_df = pd.read_csv("../test.csv")

sub_df = pd.read_csv("../sample_submission.csv")

# %%
train_df.describe(include='all').T
# Out:
#                                                   count unique       top  \
# id                                              76518.0    NaN       NaN
# Marital status                                  76518.0    NaN       NaN
# Application mode                                76518.0    NaN       NaN
# Application order                               76518.0    NaN       NaN
# Course                                          76518.0    NaN       NaN
# Daytime/evening attendance                      76518.0    NaN       NaN
# Previous qualification                          76518.0    NaN       NaN
# Previous qualification (grade)                  76518.0    NaN       NaN
# Nacionality                                     76518.0    NaN       NaN
# Mother's qualification                          76518.0    NaN       NaN
# Father's qualification                          76518.0    NaN       NaN
# Mother's occupation                             76518.0    NaN       NaN
# Father's occupation                             76518.0    NaN       NaN
# Admission grade                                 76518.0    NaN       NaN
# Displaced                                       76518.0    NaN       NaN
# Educational special needs                       76518.0    NaN       NaN
# Debtor                                          76518.0    NaN       NaN
# Tuition fees up to date                         76518.0    NaN       NaN
# Gender                                          76518.0    NaN       NaN
# Scholarship holder                              76518.0    NaN       NaN
# Age at enrollment                               76518.0    NaN       NaN
# International                                   76518.0    NaN       NaN
# Curricular units 1st sem (credited)             76518.0    NaN       NaN
# Curricular units 1st sem (enrolled)             76518.0    NaN       NaN
# Curricular units 1st sem (evaluations)          76518.0    NaN       NaN
# Curricular units 1st sem (approved)             76518.0    NaN       NaN
# Curricular units 1st sem (grade)                76518.0    NaN       NaN
# Curricular units 1st sem (without evaluations)  76518.0    NaN       NaN
# Curricular units 2nd sem (credited)             76518.0    NaN       NaN
# Curricular units 2nd sem (enrolled)             76518.0    NaN       NaN
# Curricular units 2nd sem (evaluations)          76518.0    NaN       NaN
# Curricular units 2nd sem (approved)             76518.0    NaN       NaN
# Curricular units 2nd sem (grade)                76518.0    NaN       NaN
# Curricular units 2nd sem (without evaluations)  76518.0    NaN       NaN
# Unemployment rate                               76518.0    NaN       NaN
# Inflation rate                                  76518.0    NaN       NaN
# GDP                                             76518.0    NaN       NaN
# Target                                            76518      3  Graduate
#
#                                                  freq         mean  \
# id                                                NaN      38258.5
# Marital status                                    NaN     1.111934
# Application mode                                  NaN    16.054419
# Application order                                 NaN      1.64441
# Course                                            NaN  9001.286377
# Daytime/evening attendance                        NaN     0.915314
# Previous qualification                            NaN      3.65876
# Previous qualification (grade)                    NaN   132.378766
# Nacionality                                       NaN       1.2266
# Mother's qualification                            NaN    19.837633
# Father's qualification                            NaN    23.425076
# Mother's occupation                               NaN     8.583196
# Father's occupation                               NaN     8.882172
# Admission grade                                   NaN   125.363971
# Displaced                                         NaN     0.569265
# Educational special needs                         NaN     0.003738
# Debtor                                            NaN     0.071382
# Tuition fees up to date                           NaN     0.893646
# Gender                                            NaN     0.315821
# Scholarship holder                                NaN     0.247393
# Age at enrollment                                 NaN    22.278653
# International                                     NaN     0.006626
# Curricular units 1st sem (credited)               NaN     0.188871
# Curricular units 1st sem (enrolled)               NaN     5.891516
# Curricular units 1st sem (evaluations)            NaN     7.352362
# Curricular units 1st sem (approved)               NaN      4.17852
# Curricular units 1st sem (grade)                  NaN     9.995862
# Curricular units 1st sem (without evaluations)    NaN      0.05796
# Curricular units 2nd sem (credited)               NaN     0.137053
# Curricular units 2nd sem (enrolled)               NaN     5.933414
# Curricular units 2nd sem (evaluations)            NaN     7.234468
# Curricular units 2nd sem (approved)               NaN     4.007201
# Curricular units 2nd sem (grade)                  NaN     9.626085
# Curricular units 2nd sem (without evaluations)    NaN     0.062443
# Unemployment rate                                 NaN     11.52034
# Inflation rate                                    NaN     1.228218
# GDP                                               NaN    -0.080921
# Target                                          36282          NaN
#
#                                                          std   min        25%  \
# id                                              22088.988286   0.0   19129.25
# Marital status                                      0.441669   1.0        1.0
# Application mode                                   16.682337   1.0        1.0
# Application order                                   1.229645   0.0        1.0
# Course                                           1803.438531  33.0     9119.0
# Daytime/evening attendance                          0.278416   0.0        1.0
# Previous qualification                              8.623774   1.0        1.0
# Previous qualification (grade)                     10.995328  95.0      125.0
# Nacionality                                         3.392183   1.0        1.0
# Mother's qualification                             15.399456   1.0        1.0
# Father's qualification                             14.921164   1.0        4.0
# Mother's occupation                                17.471591   0.0        4.0
# Father's occupation                                 16.80394   0.0        5.0
# Admission grade                                    12.562328  95.0      118.0
# Displaced                                           0.495182   0.0        0.0
# Educational special needs                           0.061023   0.0        0.0
# Debtor                                              0.257463   0.0        0.0
# Tuition fees up to date                             0.308292   0.0        1.0
# Gender                                              0.464845   0.0        0.0
# Scholarship holder                                    0.4315   0.0        0.0
# Age at enrollment                                   6.889241  17.0       18.0
# International                                        0.08113   0.0        0.0
# Curricular units 1st sem (credited)                 1.175296   0.0        0.0
# Curricular units 1st sem (enrolled)                 1.671776   0.0        5.0
# Curricular units 1st sem (evaluations)              3.508292   0.0        6.0
# Curricular units 1st sem (approved)                 2.687995   0.0        2.0
# Curricular units 1st sem (grade)                    5.264224   0.0  10.666667
# Curricular units 1st sem (without evaluations)       0.40849   0.0        0.0
# Curricular units 2nd sem (credited)                  0.93383   0.0        0.0
# Curricular units 2nd sem (enrolled)                 1.627182   0.0        5.0
# Curricular units 2nd sem (evaluations)               3.50304   0.0        6.0
# Curricular units 2nd sem (approved)                 2.772956   0.0        1.0
# Curricular units 2nd sem (grade)                    5.546035   0.0       10.0
# Curricular units 2nd sem (without evaluations)      0.462107   0.0        0.0
# Unemployment rate                                   2.653375   7.6        9.4
# Inflation rate                                      1.398816  -0.8        0.3
# GDP                                                 2.251382 -4.06       -1.7
# Target                                                   NaN   NaN        NaN
#
#                                                       50%        75%      max
# id                                                38258.5   57387.75  76517.0
# Marital status                                        1.0        1.0      6.0
# Application mode                                     17.0       39.0     53.0
# Application order                                     1.0        2.0      9.0
# Course                                             9254.0     9670.0   9991.0
# Daytime/evening attendance                            1.0        1.0      1.0
# Previous qualification                                1.0        1.0     43.0
# Previous qualification (grade)                      133.1      140.0    190.0
# Nacionality                                           1.0        1.0    109.0
# Mother's qualification                               19.0       37.0     44.0
# Father's qualification                               19.0       37.0     44.0
# Mother's occupation                                   7.0        9.0    194.0
# Father's occupation                                   7.0        9.0    195.0
# Admission grade                                     124.6      132.0    190.0
# Displaced                                             1.0        1.0      1.0
# Educational special needs                             0.0        0.0      1.0
# Debtor                                                0.0        0.0      1.0
# Tuition fees up to date                               1.0        1.0      1.0
# Gender                                                0.0        1.0      1.0
# Scholarship holder                                    0.0        0.0      1.0
# Age at enrollment                                    19.0       23.0     70.0
# International                                         0.0        0.0      1.0
# Curricular units 1st sem (credited)                   0.0        0.0     20.0
# Curricular units 1st sem (enrolled)                   6.0        6.0     26.0
# Curricular units 1st sem (evaluations)                7.0        9.0     45.0
# Curricular units 1st sem (approved)                   5.0        6.0     26.0
# Curricular units 1st sem (grade)                12.166667  13.314286   18.875
# Curricular units 1st sem (without evaluations)        0.0        0.0     12.0
# Curricular units 2nd sem (credited)                   0.0        0.0     19.0
# Curricular units 2nd sem (enrolled)                   6.0        6.0     23.0
# Curricular units 2nd sem (evaluations)                7.0        9.0     33.0
# Curricular units 2nd sem (approved)                   5.0        6.0     20.0
# Curricular units 2nd sem (grade)                12.142857  13.244048     18.0
# Curricular units 2nd sem (without evaluations)        0.0        0.0     12.0
# Unemployment rate                                    11.1       12.7     16.2
# Inflation rate                                        1.4        2.6      3.7
# GDP                                                  0.32       1.79     3.51
# Target                                                NaN        NaN      NaN

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              76518 non-null  int64
#  1   Marital status                                  76518 non-null  int64
#  2   Application mode                                76518 non-null  int64
#  3   Application order                               76518 non-null  int64
#  4   Course                                          76518 non-null  int64
#  5   Daytime/evening attendance                      76518 non-null  int64
#  6   Previous qualification                          76518 non-null  int64
#  7   Previous qualification (grade)                  76518 non-null  float64
#  8   Nacionality                                     76518 non-null  int64
#  9   Mother's qualification                          76518 non-null  int64
#  10  Father's qualification                          76518 non-null  int64
#  11  Mother's occupation                             76518 non-null  int64
#  12  Father's occupation                             76518 non-null  int64
#  13  Admission grade                                 76518 non-null  float64
#  14  Displaced                                       76518 non-null  int64
#  15  Educational special needs                       76518 non-null  int64
#  16  Debtor                                          76518 non-null  int64
#  17  Tuition fees up to date                         76518 non-null  int64
#  18  Gender                                          76518 non-null  int64
#  19  Scholarship holder                              76518 non-null  int64
#  20  Age at enrollment                               76518 non-null  int64
#  21  International                                   76518 non-null  int64
#  22  Curricular units 1st sem (credited)             76518 non-null  int64
#  23  Curricular units 1st sem (enrolled)             76518 non-null  int64
#  24  Curricular units 1st sem (evaluations)          76518 non-null  int64
#  25  Curricular units 1st sem (approved)             76518 non-null  int64
#  26  Curricular units 1st sem (grade)                76518 non-null  float64
#  27  Curricular units 1st sem (without evaluations)  76518 non-null  int64
#  28  Curricular units 2nd sem (credited)             76518 non-null  int64
#  29  Curricular units 2nd sem (enrolled)             76518 non-null  int64
#  30  Curricular units 2nd sem (evaluations)          76518 non-null  int64
#  31  Curricular units 2nd sem (approved)             76518 non-null  int64
#  32  Curricular units 2nd sem (grade)                76518 non-null  float64
#  33  Curricular units 2nd sem (without evaluations)  76518 non-null  int64
#  34  Unemployment rate                               76518 non-null  float64
#  35  Inflation rate                                  76518 non-null  float64
#  36  GDP                                             76518 non-null  float64
#  37  Target                                          76518 non-null  object
# dtypes: float64(7), int64(30), object(1)
# memory usage: 22.2+ MB

# %%
train_df.nunique().sort_values()
# Out:
# Gender                                                2
# International                                         2
# Scholarship holder                                    2
# Tuition fees up to date                               2
# Debtor                                                2
# Daytime/evening attendance                            2
# Educational special needs                             2
# Displaced                                             2
# Target                                                3
# Marital status                                        6
# Application order                                     8
# Unemployment rate                                    11
# Curricular units 2nd sem (without evaluations)       11
# GDP                                                  11
# Curricular units 1st sem (without evaluations)       12
# Inflation rate                                       13
# Nacionality                                          18
# Course                                               19
# Curricular units 2nd sem (credited)                  20
# Previous qualification                               21
# Curricular units 2nd sem (approved)                  21
# Curricular units 1st sem (credited)                  21
# Application mode                                     22
# Curricular units 2nd sem (enrolled)                  22
# Curricular units 1st sem (approved)                  23
# Curricular units 1st sem (enrolled)                  24
# Curricular units 2nd sem (evaluations)               31
# Mother's qualification                               35
# Curricular units 1st sem (evaluations)               36
# Father's qualification                               39
# Mother's occupation                                  40
# Age at enrollment                                    46
# Father's occupation                                  56
# Previous qualification (grade)                      110
# Admission grade                                     668
# Curricular units 1st sem (grade)                   1206
# Curricular units 2nd sem (grade)                   1234
# id                                                76518
# dtype: int64

# %%
feature_list = [feature for feature in train_df.columns if  feature  != "Target"]

target = "Target"

binary_features = ['Scholarship holder','International','Gender','Tuition fees up to date',
                   'Daytime/evening attendance','Debtor','Educational special needs','Displaced']

#from data set description
categorical_features = ['Marital status', 'Unemployment rate', 'Curricular units 2nd sem (without evaluations)', 'GDP', 
                        'Curricular units 1st sem (without evaluations)', 'Inflation rate', 'Nacionality', 'Course',
                        'Curricular units 2nd sem (credited)', 'Previous qualification', 'Curricular units 2nd sem (approved)',
                        'Curricular units 1st sem (credited)', 'Application mode', 'Curricular units 2nd sem (enrolled)', 
                        'Curricular units 1st sem (approved)', 'Curricular units 1st sem (enrolled)', 'Curricular units 2nd sem (evaluations)',
                        "Mother's qualification", 'Curricular units 1st sem (evaluations)', "Father's qualification", "Mother's occupation",
                        'Age at enrollment', "Father's occupation"]

train_df[categorical_features] = train_df[categorical_features].astype('category')
test_df[categorical_features] = test_df[categorical_features].astype('category')


numeric_features = list(set(feature_list) - set(binary_features)- set(categorical_features))

assert sorted(feature_list) == sorted(numeric_features + binary_features + categorical_features)

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

sc = StandardScaler()
oe = OneHotEncoder(drop='first', handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', sc, numeric_features),
        ('cat', oe, categorical_features),
        ('bin', 'passthrough', binary_features)
    ])

# %%
# 前処理の実行
data_preprocessed = preprocessor.fit_transform(train_df)
test_preprocessed = preprocessor.transform(test_df)

# 疎行列を密行列に変換し、書き込み可能なコピーを作成
if hasattr(data_preprocessed, 'toarray'):
    data_preprocessed = data_preprocessed.toarray()
else:
    data_preprocessed = np.array(data_preprocessed, copy=True)

if hasattr(test_preprocessed, 'toarray'):
    test_preprocessed = test_preprocessed.toarray()
else:
    test_preprocessed = np.array(test_preprocessed, copy=True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [1, 5, 6, 7, 9, 12, 13, 14, 15, 16, 17, 18, 19, 20, 22] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# OneHotEncoderによって生成された特徴量名を取得
encoded_features = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_features)

# 全ての特徴量名を結合
all_features = numeric_features + list(encoded_features) + binary_features

# 前処理されたデータをDataFrameに変換
df_preprocessed = pd.DataFrame(data_preprocessed, columns=all_features)
test_preprocessed = pd.DataFrame(test_preprocessed, columns=all_features)

# %%
X = df_preprocessed.drop('id', axis=1)
y = train_df.loc[:, 'Target']

label_mapping = {'Dropout': 0, 'Enrolled': 1, 'Graduate': 2}
encoded_y = y.map(label_mapping)

# %%
import lightgbm as lgb
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, LambdaCallback
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import VotingClassifier
from sklearn.base import BaseEstimator, ClassifierMixin
from lightgbm import LGBMClassifier
import numpy as np

# データの準備（例）
# data_preprocessed, encoded_y, test_preprocessed, test_df などを事前に用意する

# データの分割
X_train, X_val, y_train, y_val = train_test_split(X, encoded_y, test_size=0.2, random_state=42)

# SMOTEによるオーバーサンプリング
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# LightGBMのモデル定義
lgb_params = {
    'objective': 'multiclass',
    'num_class': 3,
    'metric': 'multi_logloss',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

lgb_model = LGBMClassifier(**lgb_params)
lgb_model.fit(X_train_smote, y_train_smote)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.051453 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 44282
# [LightGBM] [Info] Number of data points in the train set: 87069, number of used features: 350
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# LGBMClassifier(feature_fraction=0.9, learning_rate=0.05, metric='multi_logloss',
#                num_class=3, objective='multiclass')

# %%
from tensorflow.keras import layers, models
# Kerasのニューラルネットワークモデル定義
def create_nn_model(input_dim):
    model = Sequential()
    model.add(Input(shape=(input_dim,)))
    model.add(layers.Dense(512))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(256))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(128))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(64))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation('relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

nn_model = create_nn_model(X_train_smote.shape[1])

# アーリーストッピングのコールバック
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

nn_model.fit(X_train_smote, y_train_smote, epochs=20, batch_size=32, validation_data=(X_val, y_val), verbose=1, callbacks=[early_stopping])
# Out:
# 2024-06-27 20:07:50.035557: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-06-27 20:07:50.035628: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-06-27 20:07:50.035645: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-06-27 20:07:50.035672: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-27 20:07:50.035696: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/20
# 2024-06-27 20:07:51.449653: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 131s 47ms/step - accuracy: 0.7511 - loss: 0.6300 - val_accuracy: 0.8210 - val_loss: 0.4632
# Epoch 2/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 126s 46ms/step - accuracy: 0.8024 - loss: 0.5196 - val_accuracy: 0.8185 - val_loss: 0.4668
# Epoch 3/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 125s 46ms/step - accuracy: 0.8080 - loss: 0.4955 - val_accuracy: 0.8231 - val_loss: 0.4670
# Epoch 4/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 125s 46ms/step - accuracy: 0.8178 - loss: 0.4788 - val_accuracy: 0.8231 - val_loss: 0.4597
# Epoch 5/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 125s 46ms/step - accuracy: 0.8288 - loss: 0.4522 - val_accuracy: 0.8216 - val_loss: 0.4670
# Epoch 6/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 124s 46ms/step - accuracy: 0.8341 - loss: 0.4358 - val_accuracy: 0.8211 - val_loss: 0.4681
# Epoch 7/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 124s 46ms/step - accuracy: 0.8407 - loss: 0.4218 - val_accuracy: 0.8197 - val_loss: 0.4759
# Epoch 8/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 126s 46ms/step - accuracy: 0.8483 - loss: 0.4065 - val_accuracy: 0.8215 - val_loss: 0.4798
# Epoch 9/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 127s 47ms/step - accuracy: 0.8555 - loss: 0.3898 - val_accuracy: 0.8189 - val_loss: 0.4893
# Epoch 10/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 126s 46ms/step - accuracy: 0.8561 - loss: 0.3805 - val_accuracy: 0.8174 - val_loss: 0.4958
# Epoch 11/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 127s 47ms/step - accuracy: 0.8633 - loss: 0.3688 - val_accuracy: 0.8172 - val_loss: 0.4978
# Epoch 12/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 126s 46ms/step - accuracy: 0.8653 - loss: 0.3597 - val_accuracy: 0.8181 - val_loss: 0.5047
# Epoch 13/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 127s 47ms/step - accuracy: 0.8680 - loss: 0.3536 - val_accuracy: 0.8159 - val_loss: 0.4967
# Epoch 14/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 126s 46ms/step - accuracy: 0.8702 - loss: 0.3441 - val_accuracy: 0.8208 - val_loss: 0.5085

# %%
from tensorflow.keras.callbacks import LambdaCallback

# カスタムクラスを定義してKerasモデルをscikit-learnと統合
class KerasClassifier(BaseEstimator, ClassifierMixin):
    def __init__(self, model):
        self.model = model
        self.classes_ = np.array([0, 1, 2])  # クラスラベルの設定

    def fit(self, X, y):
        self.classes_ = np.unique(y)  # クラスラベルの更新
        early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
        log_callback = LambdaCallback(on_epoch_end=lambda epoch, logs: print(f"Epoch {epoch+1}: loss = {logs['loss']}, val_loss = {logs['val_loss']}"))
        self.model.fit(X, y, epochs=20, batch_size=32, verbose=1, validation_data=(X_val, y_val), callbacks=[early_stopping, log_callback])
        return self

    def predict(self, X):
        y_pred = self.model.predict(X)
        return np.argmax(y_pred, axis=1)

    def predict_proba(self, X):
        return self.model.predict(X)


keras_clf = KerasClassifier(model=create_nn_model(X_train_smote.shape[1]))
keras_clf.fit(X_train_smote, y_train_smote)
# Out:
# Epoch 1/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7516 - loss: 0.6347Epoch 1: loss = 0.5720400214195251, val_loss = 0.46971336007118225
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 139s 49ms/step - accuracy: 0.7517 - loss: 0.6347 - val_accuracy: 0.8163 - val_loss: 0.4697
# Epoch 2/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8008 - loss: 0.5210Epoch 2: loss = 0.5172770023345947, val_loss = 0.4580604135990143
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 128s 47ms/step - accuracy: 0.8008 - loss: 0.5210 - val_accuracy: 0.8206 - val_loss: 0.4581
# Epoch 3/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8122 - loss: 0.4989Epoch 3: loss = 0.49556833505630493, val_loss = 0.4751395881175995
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 129s 47ms/step - accuracy: 0.8122 - loss: 0.4989 - val_accuracy: 0.8203 - val_loss: 0.4751
# Epoch 4/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8184 - loss: 0.4812Epoch 4: loss = 0.47744426131248474, val_loss = 0.46173855662345886
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 130s 48ms/step - accuracy: 0.8184 - loss: 0.4812 - val_accuracy: 0.8233 - val_loss: 0.4617
# Epoch 5/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8285 - loss: 0.4510Epoch 5: loss = 0.45408347249031067, val_loss = 0.46998217701911926
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 136s 50ms/step - accuracy: 0.8285 - loss: 0.4510 - val_accuracy: 0.8223 - val_loss: 0.4700
# Epoch 6/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8342 - loss: 0.4331Epoch 6: loss = 0.43800991773605347, val_loss = 0.4702296257019043
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 130s 48ms/step - accuracy: 0.8342 - loss: 0.4331 - val_accuracy: 0.8243 - val_loss: 0.4702
# Epoch 7/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8397 - loss: 0.4248Epoch 7: loss = 0.4239375591278076, val_loss = 0.4726623296737671
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 133s 49ms/step - accuracy: 0.8397 - loss: 0.4248 - val_accuracy: 0.8220 - val_loss: 0.4727
# Epoch 8/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8465 - loss: 0.4068Epoch 8: loss = 0.4093628227710724, val_loss = 0.4784128665924072
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 132s 49ms/step - accuracy: 0.8465 - loss: 0.4068 - val_accuracy: 0.8211 - val_loss: 0.4784
# Epoch 9/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8517 - loss: 0.3983Epoch 9: loss = 0.39858123660087585, val_loss = 0.4855627119541168
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 135s 49ms/step - accuracy: 0.8517 - loss: 0.3983 - val_accuracy: 0.8207 - val_loss: 0.4856
# Epoch 10/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8575 - loss: 0.3811Epoch 10: loss = 0.3826451003551483, val_loss = 0.5025351047515869
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 131s 48ms/step - accuracy: 0.8575 - loss: 0.3811 - val_accuracy: 0.8176 - val_loss: 0.5025
# Epoch 11/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8636 - loss: 0.3687Epoch 11: loss = 0.3746042847633362, val_loss = 0.5047715902328491
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 132s 48ms/step - accuracy: 0.8636 - loss: 0.3687 - val_accuracy: 0.8204 - val_loss: 0.5048
# Epoch 12/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8659 - loss: 0.3610Epoch 12: loss = 0.3679249584674835, val_loss = 0.49691084027290344
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 132s 48ms/step - accuracy: 0.8659 - loss: 0.3610 - val_accuracy: 0.8195 - val_loss: 0.4969
# KerasClassifier(model=<Sequential name=sequential_3, built=True>)

# %%
from sklearn.ensemble import StackingClassifier

# スタッキングモデルの定義
stacking_model = StackingClassifier(
    estimators=[
        ('lgb', lgb_model),
        ('nn', keras_clf)
    ],
    final_estimator=LGBMClassifier(),
    cv=5
)
# 検証データでの予測
stacking_model.fit(X_train_smote, y_train_smote)
y_pred_ensemble = stacking_model.predict(X_val)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.053227 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 44282
# [LightGBM] [Info] Number of data points in the train set: 87069, number of used features: 350
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# [LightGBM] [Info] Start training from score -1.098612
# Epoch 1/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8102 - loss: 0.4998Epoch 1: loss = 0.4967661201953888, val_loss = 0.46354833245277405
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 142s 50ms/step - accuracy: 0.8102 - loss: 0.4998 - val_accuracy: 0.8222 - val_loss: 0.4635
# Epoch 2/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8205 - loss: 0.4728Epoch 2: loss = 0.4755867123603821, val_loss = 0.46216997504234314
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 135s 50ms/step - accuracy: 0.8205 - loss: 0.4728 - val_accuracy: 0.8231 - val_loss: 0.4622
# Epoch 3/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8282 - loss: 0.4551Epoch 3: loss = 0.4578029215335846, val_loss = 0.46832624077796936
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 132s 49ms/step - accuracy: 0.8282 - loss: 0.4551 - val_accuracy: 0.8187 - val_loss: 0.4683
# Epoch 4/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8370 - loss: 0.4329Epoch 4: loss = 0.441522479057312, val_loss = 0.48512813448905945
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 131s 48ms/step - accuracy: 0.8370 - loss: 0.4329 - val_accuracy: 0.8150 - val_loss: 0.4851
# Epoch 5/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8397 - loss: 0.4237Epoch 5: loss = 0.423841655254364, val_loss = 0.4771295487880707
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 130s 48ms/step - accuracy: 0.8398 - loss: 0.4237 - val_accuracy: 0.8215 - val_loss: 0.4771
# Epoch 6/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8469 - loss: 0.4074Epoch 6: loss = 0.4109289050102234, val_loss = 0.4787065386772156
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 133s 49ms/step - accuracy: 0.8469 - loss: 0.4074 - val_accuracy: 0.8190 - val_loss: 0.4787
# Epoch 7/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8494 - loss: 0.3942Epoch 7: loss = 0.3969407081604004, val_loss = 0.4930615723133087
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 131s 48ms/step - accuracy: 0.8494 - loss: 0.3942 - val_accuracy: 0.8193 - val_loss: 0.4931
# Epoch 8/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8570 - loss: 0.3806Epoch 8: loss = 0.38996028900146484, val_loss = 0.4880041182041168
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 132s 49ms/step - accuracy: 0.8570 - loss: 0.3806 - val_accuracy: 0.8223 - val_loss: 0.4880
# Epoch 9/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8589 - loss: 0.3784Epoch 9: loss = 0.37941092252731323, val_loss = 0.49864012002944946
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 133s 49ms/step - accuracy: 0.8589 - loss: 0.3784 - val_accuracy: 0.8176 - val_loss: 0.4986
# Epoch 10/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8640 - loss: 0.3660Epoch 10: loss = 0.3685462772846222, val_loss = 0.5111406445503235
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 132s 49ms/step - accuracy: 0.8640 - loss: 0.3660 - val_accuracy: 0.8140 - val_loss: 0.5111
# Epoch 11/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8665 - loss: 0.3589Epoch 11: loss = 0.3643125891685486, val_loss = 0.5071393847465515
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 132s 49ms/step - accuracy: 0.8665 - loss: 0.3589 - val_accuracy: 0.8157 - val_loss: 0.5071
# Epoch 12/20
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8685 - loss: 0.3510Epoch 12: loss = 0.3545819818973541, val_loss = 0.5072812438011169
# 2721/2721 ━━━━━━━━━━━━━━━━━━━━ 132s 48ms/step - accuracy: 0.8685 - loss: 0.3510 - val_accuracy: 0.8193 - val_loss: 0.5073
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.042971 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 43843
# [LightGBM] [Info] Number of data points in the train set: 69655, number of used features: 340
# [LightGBM] [Info] Start training from score -1.098627
# [LightGBM] [Info] Start training from score -1.098584
# [LightGBM] [Info] Start training from score -1.098627
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.049021 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 43882
# [LightGBM] [Info] Number of data points in the train set: 69655, number of used features: 343
# [LightGBM] [Info] Start training from score -1.098584
# [LightGBM] [Info] Start training from score -1.098627
# [LightGBM] [Info] Start training from score -1.098627
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042969 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40063
# [LightGBM] [Info] Number of data points in the train set: 69655, number of used features: 342
# [LightGBM] [Info] Start training from score -1.098584
# [LightGBM] [Info] Start training from score -1.098627
# [LightGBM] [Info] Start training from score -1.098627
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039618 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 36845
# [LightGBM] [Info] Number of data points in the train set: 69655, number of used features: 341
# [LightGBM] [Info] Start training from score -1.098627
# [LightGBM] [Info] Start training from score -1.098627
# [LightGBM] [Info] Start training from score -1.098584
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.042241 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 33846
# [LightGBM] [Info] Number of data points in the train set: 69656, number of used features: 342
# [LightGBM] [Info] Start training from score -1.098641
# [LightGBM] [Info] Start training from score -1.098598
# [LightGBM] [Info] Start training from score -1.098598
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# Epoch 1/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8140 - loss: 0.4892Epoch 1: loss = 0.4872376024723053, val_loss = 0.4657670557498932
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 119s 52ms/step - accuracy: 0.8140 - loss: 0.4892 - val_accuracy: 0.8196 - val_loss: 0.4658
# Epoch 2/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8263 - loss: 0.4635Epoch 2: loss = 0.46375563740730286, val_loss = 0.4709155559539795
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8263 - loss: 0.4635 - val_accuracy: 0.8221 - val_loss: 0.4709
# Epoch 3/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8329 - loss: 0.4411Epoch 3: loss = 0.44171643257141113, val_loss = 0.4747726321220398
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8329 - loss: 0.4411 - val_accuracy: 0.8226 - val_loss: 0.4748
# Epoch 4/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8385 - loss: 0.4243Epoch 4: loss = 0.4238552153110504, val_loss = 0.49253371357917786
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8385 - loss: 0.4243 - val_accuracy: 0.8134 - val_loss: 0.4925
# Epoch 5/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8499 - loss: 0.4010Epoch 5: loss = 0.405132919549942, val_loss = 0.4896937310695648
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.8499 - loss: 0.4010 - val_accuracy: 0.8176 - val_loss: 0.4897
# Epoch 6/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8535 - loss: 0.3893Epoch 6: loss = 0.3910648226737976, val_loss = 0.4997413456439972
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8535 - loss: 0.3893 - val_accuracy: 0.8140 - val_loss: 0.4997
# Epoch 7/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8573 - loss: 0.3781Epoch 7: loss = 0.37775617837905884, val_loss = 0.5059322714805603
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8573 - loss: 0.3781 - val_accuracy: 0.8167 - val_loss: 0.5059
# Epoch 8/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8671 - loss: 0.3585Epoch 8: loss = 0.3657945692539215, val_loss = 0.506166398525238
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8671 - loss: 0.3585 - val_accuracy: 0.8199 - val_loss: 0.5062
# Epoch 9/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8712 - loss: 0.3492Epoch 9: loss = 0.3530992269515991, val_loss = 0.5054522156715393
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 110s 50ms/step - accuracy: 0.8712 - loss: 0.3492 - val_accuracy: 0.8202 - val_loss: 0.5055
# Epoch 10/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8760 - loss: 0.3400Epoch 10: loss = 0.34642595052719116, val_loss = 0.5282971858978271
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.8760 - loss: 0.3400 - val_accuracy: 0.8140 - val_loss: 0.5283
# Epoch 11/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8762 - loss: 0.3320Epoch 11: loss = 0.3365054726600647, val_loss = 0.5278799533843994
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8762 - loss: 0.3320 - val_accuracy: 0.8166 - val_loss: 0.5279
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# Epoch 1/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8162 - loss: 0.4888Epoch 1: loss = 0.4849983751773834, val_loss = 0.47684329748153687
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 120s 53ms/step - accuracy: 0.8162 - loss: 0.4888 - val_accuracy: 0.8199 - val_loss: 0.4768
# Epoch 2/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8285 - loss: 0.4607Epoch 2: loss = 0.4616932272911072, val_loss = 0.4670513868331909
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8285 - loss: 0.4607 - val_accuracy: 0.8225 - val_loss: 0.4671
# Epoch 3/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8339 - loss: 0.4401Epoch 3: loss = 0.4414076507091522, val_loss = 0.46919459104537964
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8339 - loss: 0.4401 - val_accuracy: 0.8222 - val_loss: 0.4692
# Epoch 4/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8423 - loss: 0.4207Epoch 4: loss = 0.4248896539211273, val_loss = 0.49128925800323486
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8423 - loss: 0.4207 - val_accuracy: 0.8187 - val_loss: 0.4913
# Epoch 5/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8511 - loss: 0.4003Epoch 5: loss = 0.4039638042449951, val_loss = 0.4822022616863251
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8511 - loss: 0.4003 - val_accuracy: 0.8210 - val_loss: 0.4822
# Epoch 6/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8539 - loss: 0.3905Epoch 6: loss = 0.3907143473625183, val_loss = 0.493683397769928
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8539 - loss: 0.3905 - val_accuracy: 0.8159 - val_loss: 0.4937
# Epoch 7/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8614 - loss: 0.3730Epoch 7: loss = 0.3758589029312134, val_loss = 0.5034902095794678
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8614 - loss: 0.3730 - val_accuracy: 0.8165 - val_loss: 0.5035
# Epoch 8/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8654 - loss: 0.3605Epoch 8: loss = 0.3660754859447479, val_loss = 0.5063778162002563
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8654 - loss: 0.3605 - val_accuracy: 0.8184 - val_loss: 0.5064
# Epoch 9/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8711 - loss: 0.3452Epoch 9: loss = 0.3519136905670166, val_loss = 0.5198795795440674
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8711 - loss: 0.3452 - val_accuracy: 0.8119 - val_loss: 0.5199
# Epoch 10/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8728 - loss: 0.3431Epoch 10: loss = 0.3430764973163605, val_loss = 0.5234993100166321
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8728 - loss: 0.3431 - val_accuracy: 0.8185 - val_loss: 0.5235
# Epoch 11/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8787 - loss: 0.3255Epoch 11: loss = 0.33636927604675293, val_loss = 0.5206759572029114
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8787 - loss: 0.3255 - val_accuracy: 0.8176 - val_loss: 0.5207
# Epoch 12/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8807 - loss: 0.3229Epoch 12: loss = 0.3275463283061981, val_loss = 0.5352680087089539
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 105s 48ms/step - accuracy: 0.8807 - loss: 0.3229 - val_accuracy: 0.8136 - val_loss: 0.5353
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# Epoch 1/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8077 - loss: 0.5081Epoch 1: loss = 0.5049528479576111, val_loss = 0.4746386706829071
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 119s 52ms/step - accuracy: 0.8077 - loss: 0.5081 - val_accuracy: 0.8136 - val_loss: 0.4746
# Epoch 2/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8160 - loss: 0.4814Epoch 2: loss = 0.48296621441841125, val_loss = 0.4682808518409729
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.8160 - loss: 0.4814 - val_accuracy: 0.8240 - val_loss: 0.4683
# Epoch 3/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8209 - loss: 0.4707Epoch 3: loss = 0.46810099482536316, val_loss = 0.4644484519958496
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8209 - loss: 0.4707 - val_accuracy: 0.8210 - val_loss: 0.4644
# Epoch 4/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8319 - loss: 0.4484Epoch 4: loss = 0.45054954290390015, val_loss = 0.4704696536064148
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 106s 49ms/step - accuracy: 0.8319 - loss: 0.4484 - val_accuracy: 0.8218 - val_loss: 0.4705
# Epoch 5/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8348 - loss: 0.4346Epoch 5: loss = 0.4349377155303955, val_loss = 0.4789102375507355
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.8348 - loss: 0.4346 - val_accuracy: 0.8193 - val_loss: 0.4789
# Epoch 6/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8438 - loss: 0.4164Epoch 6: loss = 0.42116478085517883, val_loss = 0.4906945526599884
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.8438 - loss: 0.4164 - val_accuracy: 0.8185 - val_loss: 0.4907
# Epoch 7/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8476 - loss: 0.4054Epoch 7: loss = 0.4089869558811188, val_loss = 0.47874170541763306
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8476 - loss: 0.4054 - val_accuracy: 0.8204 - val_loss: 0.4787
# Epoch 8/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8533 - loss: 0.3872Epoch 8: loss = 0.39602816104888916, val_loss = 0.49369359016418457
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 109s 50ms/step - accuracy: 0.8533 - loss: 0.3872 - val_accuracy: 0.8192 - val_loss: 0.4937
# Epoch 9/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8552 - loss: 0.3824Epoch 9: loss = 0.38971561193466187, val_loss = 0.497014582157135
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 108s 50ms/step - accuracy: 0.8552 - loss: 0.3824 - val_accuracy: 0.8188 - val_loss: 0.4970
# Epoch 10/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8586 - loss: 0.3763Epoch 10: loss = 0.38072946667671204, val_loss = 0.5104802846908569
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.8586 - loss: 0.3763 - val_accuracy: 0.8169 - val_loss: 0.5105
# Epoch 11/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8615 - loss: 0.3676Epoch 11: loss = 0.3704368770122528, val_loss = 0.5054349303245544
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8615 - loss: 0.3676 - val_accuracy: 0.8181 - val_loss: 0.5054
# Epoch 12/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8674 - loss: 0.3547Epoch 12: loss = 0.36305540800094604, val_loss = 0.5162761807441711
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 108s 50ms/step - accuracy: 0.8674 - loss: 0.3547 - val_accuracy: 0.8146 - val_loss: 0.5163
# Epoch 13/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8686 - loss: 0.3474Epoch 13: loss = 0.3541620373725891, val_loss = 0.5186815857887268
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 107s 49ms/step - accuracy: 0.8686 - loss: 0.3474 - val_accuracy: 0.8174 - val_loss: 0.5187
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
# Epoch 1/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8103 - loss: 0.5045Epoch 1: loss = 0.5043482780456543, val_loss = 0.45705440640449524
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 120s 53ms/step - accuracy: 0.8103 - loss: 0.5045 - val_accuracy: 0.8240 - val_loss: 0.4571
# Epoch 2/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8125 - loss: 0.4874Epoch 2: loss = 0.4854421019554138, val_loss = 0.4817444384098053
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 108s 49ms/step - accuracy: 0.8125 - loss: 0.4874 - val_accuracy: 0.8119 - val_loss: 0.4817
# Epoch 3/20
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8207 - loss: 0.4685Epoch 3: loss = 0.46933916211128235, val_loss = 0.47892358899116516
# 2177/2177 ━━━━━━━━━━━━━━━━━━━━ 111s 51ms/step - accuracy: 0.8207 - loss: 0.4685 - val_accuracy: 0.8176 - val_loss: 0.4789
# Epoch 4/20
# 1266/2177 ━━━━━━━━━━━━━━━━━━━━ 48s 53ms/step - accuracy: 0.8295 - loss: 0.4484
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 13
#       4 stacking_model = StackingClassifier(
#       5     estimators=[
#       6         ('lgb', lgb_model),
#    (...)
#      10     cv=5
#      11 )
#      12 # 検証データでの予測
# ---> 13 stacking_model.fit(X_train_smote, y_train_smote)
#      14 y_pred_ensemble = stacking_model.predict(X_val)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_stacking.py:672, in StackingClassifier.fit(self, X, y, sample_weight)
#     670     self.classes_ = self._label_encoder.classes_
#     671     y_encoded = self._label_encoder.transform(y)
# --> 672 return super().fit(X, y_encoded, sample_weight)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_stacking.py:264, in _BaseStacking.fit(self, X, y, sample_weight)
#     261     if hasattr(cv, "random_state") and cv.random_state is None:
#     262         cv.random_state = np.random.RandomState()
# --> 264     predictions = Parallel(n_jobs=self.n_jobs)(
#     265         delayed(cross_val_predict)(
#     266             clone(est),
#     267             X,
#     268             y,
#     269             cv=deepcopy(cv),
#     270             method=meth,
#     271             n_jobs=self.n_jobs,
#     272             params=fit_params,
#     273             verbose=self.verbose,
#     274         )
#     275         for est, meth in zip(all_estimators, self.stack_method_)
#     276         if est != "drop"
#     277     )
#     279 # Only not None or not 'drop' estimators will be used in transform.
#     280 # Remove the None from the method as well.
#     281 self.stack_method_ = [
#     282     meth
#     283     for (meth, est) in zip(self.stack_method_, all_estimators)
#     284     if est != "drop"
#     285 ]
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:1282, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, params, pre_dispatch, method)
#    1279 # We clone the estimator to make sure that all the folds are
#    1280 # independent, and that it is pickle-able.
#    1281 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# -> 1282 predictions = parallel(
#    1283     delayed(_fit_and_predict)(
#    1284         clone(estimator),
#    1285         X,
#    1286         y,
#    1287         train,
#    1288         test,
#    1289         routed_params.estimator.fit,
#    1290         method,
#    1291     )
#    1292     for train, test in splits
#    1293 )
#    1295 inv_test_indices = np.empty(len(test_indices), dtype=int)
#    1296 inv_test_indices[test_indices] = np.arange(len(test_indices))
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:1367, in _fit_and_predict(estimator, X, y, train, test, fit_params, method)
#    1365     estimator.fit(X_train, **fit_params)
#    1366 else:
# -> 1367     estimator.fit(X_train, y_train, **fit_params)
#    1368 func = getattr(estimator, method)
#    1369 predictions = func(X_test)
#
# Cell In[16], line 13, in KerasClassifier.fit(self, X, y)
#      11 early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
#      12 log_callback = LambdaCallback(on_epoch_end=lambda epoch, logs: print(f"Epoch {epoch+1}: loss = {logs['loss']}, val_loss = {logs['val_loss']}"))
# ---> 13 self.model.fit(X, y, epochs=20, batch_size=32, verbose=1, validation_data=(X_val, y_val), callbacks=[early_stopping, log_callback])
#      14 return self
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# 評価
accuracy_ensemble = accuracy_score(y_val, y_pred_ensemble)
print(f'Ensemble Validation Accuracy: {accuracy_ensemble}')
print(classification_report(y_val, y_pred_ensemble))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # 評価
# ----> 2 accuracy_ensemble = accuracy_score(y_val, y_pred_ensemble)
#       3 print(f'Ensemble Validation Accuracy: {accuracy_ensemble}')
#       4 print(classification_report(y_val, y_pred_ensemble))
#
# NameError: name 'y_pred_ensemble' is not defined

# %%
# テストデータに対する予測
test_preprocessed = test_preprocessed.drop('id', axis=1)
test_pred_ensemble = stacking_model.predict(test_preprocessed)

# ターゲット値に変換
target_mapping = {0: 'Dropout', 1: 'Enrolled', 2: 'Graduate'}
final_predictions = [target_mapping[pred] for pred in test_pred_ensemble]

# 結果をデータフレームに格納
results_df = pd.DataFrame(data={"id": test_df['id'], "Target": final_predictions})

# 結果を保存
results_df.to_csv('submission_ensemble2.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# 1595/1595 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 # テストデータに対する予測
#       2 test_preprocessed = test_preprocessed.drop('id', axis=1)
# ----> 3 test_pred_ensemble = stacking_model.predict(test_preprocessed)
#       5 # ターゲット値に変換
#       6 target_mapping = {0: 'Dropout', 1: 'Enrolled', 2: 'Graduate'}
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_stacking.py:695, in StackingClassifier.predict(self, X, **predict_params)
#     674 @available_if(_estimator_has("predict"))
#     675 def predict(self, X, **predict_params):
#     676     """Predict target for X.
#     677
#     678     Parameters
#    (...)
#     693         Predicted targets.
#     694     """
# --> 695     y_pred = super().predict(X, **predict_params)
#     696     if isinstance(self._label_encoder, list):
#     697         # Handle the multilabel-indicator case
#     698         y_pred = np.array(
#     699             [
#     700                 self._label_encoder[target_idx].inverse_transform(target)
#     701                 for target_idx, target in enumerate(y_pred.T)
#     702             ]
#     703         ).T
#
# File /opt/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_stacking.py:382, in _BaseStacking.predict(self, X, **predict_params)
#     361 """Predict target for X.
#     362
#     363 Parameters
#    (...)
#     378     Predicted targets.
#     379 """
#     381 check_is_fitted(self)
# --> 382 return self.final_estimator_.predict(self.transform(X), **predict_params)
#
# File /opt/anaconda3/lib/python3.11/site-packages/lightgbm/sklearn.py:1223, in LGBMClassifier.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#    1211 def predict(
#    1212     self,
#    1213     X: _LGBM_ScikitMatrixLike,
#    (...)
#    1220     **kwargs: Any
#    1221 ):
#    1222     """Docstring is inherited from the LGBMModel."""
# -> 1223     result = self.predict_proba(
#    1224         X=X,
#    1225         raw_score=raw_score,
#    1226         start_iteration=start_iteration,
#    1227         num_iteration=num_iteration,
#    1228         pred_leaf=pred_leaf,
#    1229         pred_contrib=pred_contrib,
#    1230         validate_features=validate_features,
#    1231         **kwargs
#    1232     )
#    1233     if callable(self._objective) or raw_score or pred_leaf or pred_contrib:
#    1234         return result
#
# File /opt/anaconda3/lib/python3.11/site-packages/lightgbm/sklearn.py:1253, in LGBMClassifier.predict_proba(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#    1241 def predict_proba(
#    1242     self,
#    1243     X: _LGBM_ScikitMatrixLike,
#    (...)
#    1250     **kwargs: Any
#    1251 ):
#    1252     """Docstring is set after definition, using a template."""
# -> 1253     result = super().predict(
#    1254         X=X,
#    1255         raw_score=raw_score,
#    1256         start_iteration=start_iteration,
#    1257         num_iteration=num_iteration,
#    1258         pred_leaf=pred_leaf,
#    1259         pred_contrib=pred_contrib,
#    1260         validate_features=validate_features,
#    1261         **kwargs
#    1262     )
#    1263     if callable(self._objective) and not (raw_score or pred_leaf or pred_contrib):
#    1264         _log_warning("Cannot compute class probabilities or labels "
#    1265                      "due to the usage of customized objective function.\n"
#    1266                      "Returning raw scores instead.")
#
# File /opt/anaconda3/lib/python3.11/site-packages/lightgbm/sklearn.py:932, in LGBMModel.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#     930 """Docstring is set after definition, using a template."""
#     931 if not self.__sklearn_is_fitted__():
# --> 932     raise LGBMNotFittedError("Estimator not fitted, call fit before exploiting the model.")
#     933 if not isinstance(X, (pd_DataFrame, dt_DataTable)):
#     934     X = _LGBMCheckArray(X, accept_sparse=True, force_all_finite=False)
#
# NotFittedError: Estimator not fitted, call fit before exploiting the model.
